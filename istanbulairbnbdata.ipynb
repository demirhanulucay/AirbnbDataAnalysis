# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import folium
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/zillow-market-analysis-and-real-estate-sales-data/market_analysis.csv
# /kaggle/input/zillow-market-analysis-and-real-estate-sales-data/geolocation.csv
# /kaggle/input/zillow-market-analysis-and-real-estate-sales-data/sales_properties_total_zipcode_92252.csv
# /kaggle/input/zillow-market-analysis-and-real-estate-sales-data/sales_properties_total_zipcode_92284.csv
# /kaggle/input/zillow-market-analysis-and-real-estate-sales-data/sales_properties_total_zipcode_92314.csv
# /kaggle/input/zillow-market-analysis-and-real-estate-sales-data/sales_properties_with_pool_zipcode_92284.csv
# /kaggle/input/zillow-market-analysis-and-real-estate-sales-data/market_analysis_2019.csv
# /kaggle/input/zillow-market-analysis-and-real-estate-sales-data/sales_properties_total_zipcode_92315.csv
# /kaggle/input/zillow-market-analysis-and-real-estate-sales-data/sales_properties_with_pool_zipcode_92252.csv
# /kaggle/input/zillow-market-analysis-and-real-estate-sales-data/amenities.csv
# /kaggle/input/airbnb-istanbul-dataset/AirbnbIstanbul.csv

# %%
df = pd.read_csv("../input/airbnb-istanbul-dataset/AirbnbIstanbul.csv")

# %%
df.head()
# Out:
#       id                                 name  host_id host_name  \
# 0   4826                            The Place     6603      Kaan
# 1  20815    The Bosphorus from The Comfy Hill    78838    Gülder
# 2  25436  House for vacation rental furnutare   105823     Yesim
# 3  27271      LOVELY APT. IN PERFECT LOCATION   117026     Mutlu
# 4  28277       Duplex Apartment with Terrace    121607      Alen
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0                  NaN       Uskudar  41.05650   29.05367  Entire home/apt
# 1                  NaN      Besiktas  41.06984   29.04545  Entire home/apt
# 2                  NaN      Besiktas  41.07731   29.03891  Entire home/apt
# 3                  NaN       Beyoglu  41.03220   28.98216  Entire home/apt
# 4                  NaN         Sisli  41.04471   28.98567  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    554               1                  1  2009-06-01               0.01
# 1    100              30                 41  2018-11-07               0.38
# 2    211              21                  0         NaN                NaN
# 3    237               5                  2  2018-05-04               0.04
# 4    591               3                  0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# 0                               1               365
# 1                               2                49
# 2                               1                83
# 3                               1               228
# 4                              13               356

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16251 entries, 0 to 16250
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              16251 non-null  int64
#  1   name                            16160 non-null  object
#  2   host_id                         16251 non-null  int64
#  3   host_name                       16244 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   16251 non-null  object
#  6   latitude                        16251 non-null  float64
#  7   longitude                       16251 non-null  float64
#  8   room_type                       16251 non-null  object
#  9   price                           16251 non-null  int64
#  10  minimum_nights                  16251 non-null  int64
#  11  number_of_reviews               16251 non-null  int64
#  12  last_review                     7767 non-null   object
#  13  reviews_per_month               7767 non-null   float64
#  14  calculated_host_listings_count  16251 non-null  int64
#  15  availability_365                16251 non-null  int64
# dtypes: float64(4), int64(7), object(5)
# memory usage: 2.0+ MB

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 91
# host_id                               0
# host_name                             7
# neighbourhood_group               16251
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        8484
# reviews_per_month                  8484
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.drop(columns="neighbourhood_group", inplace = True)
df.drop(columns="last_review", inplace = True)

# %%
df.head()
# Out:
#       id                                 name  host_id host_name  \
# 0   4826                            The Place     6603      Kaan
# 1  20815    The Bosphorus from The Comfy Hill    78838    Gülder
# 2  25436  House for vacation rental furnutare   105823     Yesim
# 3  27271      LOVELY APT. IN PERFECT LOCATION   117026     Mutlu
# 4  28277       Duplex Apartment with Terrace    121607      Alen
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0       Uskudar  41.05650   29.05367  Entire home/apt    554               1
# 1      Besiktas  41.06984   29.04545  Entire home/apt    100              30
# 2      Besiktas  41.07731   29.03891  Entire home/apt    211              21
# 3       Beyoglu  41.03220   28.98216  Entire home/apt    237               5
# 4         Sisli  41.04471   28.98567  Entire home/apt    591               3
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                  1               0.01                               1
# 1                 41               0.38                               2
# 2                  0                NaN                               1
# 3                  2               0.04                               1
# 4                  0                NaN                              13
#
#    availability_365
# 0               365
# 1                49
# 2                83
# 3               228
# 4               356

# %%
df["reviews_per_month"].fillna(0, inplace=True)
# Out:
# /tmp/ipykernel_18/3157826511.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["reviews_per_month"].fillna(0, inplace=True)

# %%
df.head()
# Out:
#       id                                 name  host_id host_name  \
# 0   4826                            The Place     6603      Kaan
# 1  20815    The Bosphorus from The Comfy Hill    78838    Gülder
# 2  25436  House for vacation rental furnutare   105823     Yesim
# 3  27271      LOVELY APT. IN PERFECT LOCATION   117026     Mutlu
# 4  28277       Duplex Apartment with Terrace    121607      Alen
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0       Uskudar  41.05650   29.05367  Entire home/apt    554               1
# 1      Besiktas  41.06984   29.04545  Entire home/apt    100              30
# 2      Besiktas  41.07731   29.03891  Entire home/apt    211              21
# 3       Beyoglu  41.03220   28.98216  Entire home/apt    237               5
# 4         Sisli  41.04471   28.98567  Entire home/apt    591               3
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                  1               0.01                               1
# 1                 41               0.38                               2
# 2                  0               0.00                               1
# 3                  2               0.04                               1
# 4                  0               0.00                              13
#
#    availability_365
# 0               365
# 1                49
# 2                83
# 3               228
# 4               356

# %%
df["reviews_per_month"].fillna(0, inplace=True)
# Out:
# /tmp/ipykernel_18/1901275697.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["reviews_per_month"].fillna(0, inplace=True)

# %%
df.head()
# Out:
#       id                                 name  host_id host_name  \
# 0   4826                            The Place     6603      Kaan
# 1  20815    The Bosphorus from The Comfy Hill    78838    Gülder
# 2  25436  House for vacation rental furnutare   105823     Yesim
# 3  27271      LOVELY APT. IN PERFECT LOCATION   117026     Mutlu
# 4  28277       Duplex Apartment with Terrace    121607      Alen
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0       Uskudar  41.05650   29.05367  Entire home/apt    554               1
# 1      Besiktas  41.06984   29.04545  Entire home/apt    100              30
# 2      Besiktas  41.07731   29.03891  Entire home/apt    211              21
# 3       Beyoglu  41.03220   28.98216  Entire home/apt    237               5
# 4         Sisli  41.04471   28.98567  Entire home/apt    591               3
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                  1               0.01                               1
# 1                 41               0.38                               2
# 2                  0               0.00                               1
# 3                  2               0.04                               1
# 4                  0               0.00                              13
#
#    availability_365
# 0               365
# 1                49
# 2                83
# 3               228
# 4               356

# %%
df["neighbourhood"].unique()
# Out:
# array(['Uskudar', 'Besiktas', 'Beyoglu', 'Sisli', 'Sariyer', 'Beykoz',
#        'Atasehir', 'Fatih', 'Adalar', 'Kadikoy', 'Kagithane', 'Maltepe',
#        'Bakirkoy', 'Esenyurt', 'Basaksehir', 'Kartal', 'Gaziosmanpasa',
#        'Bahcelievler', 'Bagcilar', 'Buyukcekmece', 'Silivri',
#        'Beylikduzu', 'Umraniye', 'Sile', 'Cekmekoy', 'Sancaktepe',
#        'Tuzla', 'Pendik', 'Sultangazi', 'Eyup', 'Zeytinburnu',
#        'Kucukcekmece', 'Avcilar', 'Gungoren', 'Catalca', 'Bayrampasa',
#        'Esenler', 'Sultanbeyli', 'Arnavutkoy'], dtype=object)

# %%
df["neighbourhood"].value_counts()
# Out:
# neighbourhood
# Beyoglu          4245
# Sisli            2348
# Fatih            2146
# Kadikoy          1717
# Besiktas         1367
# Uskudar           594
# Esenyurt          378
# Kagithane         357
# Sariyer           299
# Maltepe           261
# Atasehir          258
# Bakirkoy          197
# Bahcelievler      186
# Adalar            162
# Pendik            144
# Umraniye          136
# Basaksehir        131
# Eyup              126
# Kartal            125
# Avcilar           118
# Kucukcekmece      112
# Buyukcekmece      107
# Bagcilar           91
# Beykoz             88
# Zeytinburnu        75
# Beylikduzu         70
# Sile               59
# Gaziosmanpasa      59
# Tuzla              57
# Gungoren           57
# Cekmekoy           42
# Sancaktepe         30
# Silivri            25
# Sultangazi         18
# Bayrampasa         18
# Esenler            18
# Sultanbeyli        17
# Arnavutkoy          7
# Catalca             6
# Name: count, dtype: int64

# %%
df["room_type"].unique()
df["room_type"].value_counts()
# Out:
# room_type
# Private room       8565
# Entire home/apt    7191
# Shared room         495
# Name: count, dtype: int64

# %%
df["host_id"].value_counts().head(10)
# Out:
# host_id
# 21907588     77
# 10147889     58
# 213157136    37
# 461533       29
# 21351250     27
# 2999837      25
# 21792167     24
# 189516806    23
# 21171234     23
# 1938185      21
# Name: count, dtype: int64

# %%
chart1 = df["host_id"].value_counts().head(10).plot(kind="bar")
chart1.set_title(" Hosts with Most Listings")
chart1.set_xlabel("Host ID")
chart1.set_ylabel("Number of Listings")
# Out:
# Text(0, 0.5, 'Number of Listings')

# %%
chart2 = df["neighbourhood"].value_counts().head(10).plot(kind="bar")
chart2.set_title(" Neighbourhoods with Most Listings")
chart2.set_xlabel("Neighbourhoods")
chart2.set_ylabel("Number of Listings")
# Out:
# Text(0, 0.5, 'Number of Listings')

# %%
neighbourhood_price = df.groupby("neighbourhood")["price"].agg(['mean'])

# %%
neighbourhood_price.sort_values(by='mean', ascending=False)
# Out:
#                       mean
# neighbourhood
# Kucukcekmece   1263.464286
# Catalca         885.666667
# Beykoz          855.977273
# Sariyer         660.304348
# Silivri         634.960000
# Bayrampasa      596.444444
# Buyukcekmece    571.140187
# Arnavutkoy      533.285714
# Sile            501.949153
# Fatih           498.931034
# Basaksehir      415.374046
# Adalar          406.598765
# Esenyurt        403.129630
# Bagcilar        388.978022
# Beyoglu         373.177150
# Sisli           342.175894
# Zeytinburnu     333.093333
# Atasehir        303.616279
# Besiktas        299.486467
# Eyup            297.214286
# Kartal          289.736000
# Tuzla           277.736842
# Bakirkoy        277.710660
# Gaziosmanpasa   257.576271
# Gungoren        244.105263
# Uskudar         242.510101
# Sultangazi      235.222222
# Cekmekoy        232.833333
# Esenler         231.111111
# Maltepe         225.203065
# Beylikduzu      224.385714
# Kadikoy         204.389051
# Kagithane       203.263305
# Bahcelievler    188.822581
# Umraniye        183.919118
# Avcilar         180.584746
# Sultanbeyli     178.705882
# Sancaktepe      160.266667
# Pendik          153.506944

# %%
chart3 = neighbourhood_price.sort_values(by='mean', ascending=False).head(10).plot(kind = "bar")
chart3.set_ylabel('Price TRY')
chart3.set_xlabel('Neighbourhoods')
chart3.set_title("Average Price of Neighbourhoods")
# Out:
# Text(0.5, 1.0, 'Average Price of Neighbourhoods')

# %%
most_expensive_prices = df[df.price>5000].sort_values(by="price", ascending=False).head(10)
most_expensive_prices
# Out:
#              id                                               name    host_id  \
# 13899  30361326     3 Rooms 1 Living Room - Grand Holiday Istanbul  227944870
# 13900  30361470  3 Rooms 1 Living Room Dublex - Grand Holiday I...  227944870
# 15693  31974054              Elegance Single Room - Avicenna Hotel  166950259
# 8331   22119662                               Gunluk kiralik daire  161593238
# 12745  29257295                        İstanbul town history place   20973637
# 7396   19619789                      CoZy room in Beyoğlu/cihangir   36781586
# 7619   20275354  İstanbul un kalbi sisli. Center of istanbul sisli  118695718
# 3457    7016669                 Private room in Beyoğlu(nice view)   36781586
# 7254   19235485                                               hmgv  134667922
# 5823   13703737                         Room in the center BOMONTI    3162918
#
#       host_name neighbourhood  latitude  longitude        room_type  price  \
# 13899     Ilhan  Kucukcekmece  41.03740   28.79435     Private room  59561
# 13900     Ilhan  Kucukcekmece  41.03841   28.79471     Private room  59561
# 15693  Avicenna         Fatih  41.00445   28.97907     Private room  59561
# 8331     Leylan      Esenyurt  41.02681   28.62680  Entire home/apt  52728
# 12745      Memo         Fatih  41.00850   28.96649     Private room  52243
# 7396       Kaan       Beyoglu  41.03015   28.98064     Private room  52000
# 7619       Ipek         Sisli  41.05465   28.98111     Private room  48842
# 3457       Kaan       Beyoglu  41.03383   28.97151     Private room  44671
# 7254      Deniz       Kadikoy  40.99484   29.02976      Shared room  29786
# 5823    Cagatay         Sisli  41.05709   28.98525     Private room  26364
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 13899               1                  0               0.00
# 13900               1                  0               0.00
# 15693               1                  0               0.00
# 8331                5                  0               0.00
# 12745               2                  3               0.75
# 7396                1                  1               0.05
# 7619                2                  0               0.00
# 3457                1                 13               0.30
# 7254              300                  0               0.00
# 5823                1                  0               0.00
#
#        calculated_host_listings_count  availability_365
# 13899                               3               360
# 13900                               3               331
# 15693                               4               363
# 8331                                1                 0
# 12745                               1               359
# 7396                                2                89
# 7619                                1                 0
# 3457                                2               363
# 7254                                1               364
# 5823                                1               364

# %%
city_pos = [df.latitude.mean(),df.longitude.mean()]
istanbul_map = folium.Map(location=city_pos, zoom_start=10)
folium.Marker(
    location=[41.03740, 28.79435],
    popup='3 Rooms 1 Living Room - Grand Holiday Istanbul',
    icon=folium.Icon(icon='cloud')).add_to(istanbul_map)
folium.Marker(
    location=[41.03841, 28.79471],
    popup='3 Rooms 1 Living Room Dublex - Grand Holiday Istanbul',
    icon=folium.Icon(icon='cloud')).add_to(istanbul_map)
folium.Marker(
    location=[41.00445, 28.97907],
    popup='Elegance Single Room - Avicenna Hotel',
    icon=folium.Icon(icon='cloud')).add_to(istanbul_map)
folium.Marker(
    location=[41.02681, 28.62680],
    popup='Gunluk kiralik daire',
    icon=folium.Icon(icon='cloud')).add_to(istanbul_map)
folium.Marker(
    location=[41.00850, 28.96649],
    popup='Istanbul town history place ',
    icon=folium.Icon(icon='cloud')).add_to(istanbul_map)
folium.Marker(
    location=[41.03015, 28.98064],
    popup='CoZy room in Beyoğlu/cihangir',
    icon=folium.Icon(icon='cloud')).add_to(istanbul_map)
folium.Marker(
    location=[41.05465, 28.98111],
    popup='İstanbul un kalbi sisli. Center of istanbul sisli',
    icon=folium.Icon(icon='cloud')).add_to(istanbul_map)
folium.Marker(
    location=[41.03383, 28.97151],
    popup='Private room in Beyoğlu(nice view)',
    icon=folium.Icon(icon='cloud')).add_to(istanbul_map)
folium.Marker(
    location=[40.99484, 29.02976],
    popup='hmgv',
    icon=folium.Icon(icon='cloud')).add_to(istanbul_map)
folium.Marker(
    location=[41.05709, 28.98525],
    popup='Room in the center BOMONTI',
    icon=folium.Icon(icon='cloud')).add_to(istanbul_map)

istanbul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63c22982844ec13eb6ef035aebcab8fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63c22982844ec13eb6ef035aebcab8fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63c22982844ec13eb6ef035aebcab8fa = L.map(
#                 &quot;map_63c22982844ec13eb6ef035aebcab8fa&quot;,
#                 {
#                     center: [41.02645848009353, 28.985388049966154],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d155ac5ccbc40c9f8f4989706838c3e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1d155ac5ccbc40c9f8f4989706838c3e.addTo(map_63c22982844ec13eb6ef035aebcab8fa);
#
#
#             var marker_d025e951e85c9ef6a608b1a5b84bfc82 = L.marker(
#                 [41.0374, 28.79435],
#                 {}
#             ).addTo(map_63c22982844ec13eb6ef035aebcab8fa);
#
#
#             var icon_d6226e17ee7fa0bba1016ac54056484c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d025e951e85c9ef6a608b1a5b84bfc82.setIcon(icon_d6226e17ee7fa0bba1016ac54056484c);
#
#
#         var popup_0d7164843042265e536b4129720bcb6c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c4512472c03c7883f2e5754e89f71936 = $(`&lt;div id=&quot;html_c4512472c03c7883f2e5754e89f71936&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3 Rooms 1 Living Room - Grand Holiday Istanbul&lt;/div&gt;`)[0];
#                 popup_0d7164843042265e536b4129720bcb6c.setContent(html_c4512472c03c7883f2e5754e89f71936);
#
#
#
#         marker_d025e951e85c9ef6a608b1a5b84bfc82.bindPopup(popup_0d7164843042265e536b4129720bcb6c)
#         ;
#
#
#
#
#             var marker_ca23c7822e85122f48fb5f4750257805 = L.marker(
#                 [41.03841, 28.79471],
#                 {}
#             ).addTo(map_63c22982844ec13eb6ef035aebcab8fa);
#
#
#             var icon_b0079767220fba979d3f81c83d26b958 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ca23c7822e85122f48fb5f4750257805.setIcon(icon_b0079767220fba979d3f81c83d26b958);
#
#
#         var popup_050329ef0964af7ed66a2aac9407cc0a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_723d817e3ebbdc0ad9679cee291680c3 = $(`&lt;div id=&quot;html_723d817e3ebbdc0ad9679cee291680c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3 Rooms 1 Living Room Dublex - Grand Holiday Istanbul&lt;/div&gt;`)[0];
#                 popup_050329ef0964af7ed66a2aac9407cc0a.setContent(html_723d817e3ebbdc0ad9679cee291680c3);
#
#
#
#         marker_ca23c7822e85122f48fb5f4750257805.bindPopup(popup_050329ef0964af7ed66a2aac9407cc0a)
#         ;
#
#
#
#
#             var marker_dc2b3facfcfa17cf24c9bf33ad6ac83e = L.marker(
#                 [41.00445, 28.97907],
#                 {}
#             ).addTo(map_63c22982844ec13eb6ef035aebcab8fa);
#
#
#             var icon_82bf31129067bd2b26ab08e1523e25d1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dc2b3facfcfa17cf24c9bf33ad6ac83e.setIcon(icon_82bf31129067bd2b26ab08e1523e25d1);
#
#
#         var popup_e7f0b85645e79549ea7b59f4eb9e5aa3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_716a7a27fa7e54e10f71c4ac0ca9e8d7 = $(`&lt;div id=&quot;html_716a7a27fa7e54e10f71c4ac0ca9e8d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Elegance Single Room - Avicenna Hotel&lt;/div&gt;`)[0];
#                 popup_e7f0b85645e79549ea7b59f4eb9e5aa3.setContent(html_716a7a27fa7e54e10f71c4ac0ca9e8d7);
#
#
#
#         marker_dc2b3facfcfa17cf24c9bf33ad6ac83e.bindPopup(popup_e7f0b85645e79549ea7b59f4eb9e5aa3)
#         ;
#
#
#
#
#             var marker_e7c22f23f6d8611301cd3b62fbda61fd = L.marker(
#                 [41.02681, 28.6268],
#                 {}
#             ).addTo(map_63c22982844ec13eb6ef035aebcab8fa);
#
#
#             var icon_bc22c1be9945ae9b00034a504a750dd6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &q

# %%
ave_price=df[df.price < 1500]
chart4=ave_price.plot(kind='scatter', x='longitude', y='latitude', label='availability_365', c='price', cmap=plt.get_cmap('jet'), colorbar=True, alpha=0.4, figsize=(10,6))
chart4.set_title('Price Map of Istanbul')
chart4.set_xlabel('longitude')
chart4.legend()

# %%
most_reviewed = df.nlargest(10, "number_of_reviews")
most_reviewed
# Out:
#            id                                    name   host_id    host_name  \
# 652   1092753          The Atatürk Airport, 5 minutes   6003668  Melik Fırat
# 469    847765        Sweet Flat in Cihangir Cukurcuma   2769925        Pelin
# 891   1589084       Sultanahmet Gardens: Double Suite    923172       Tansel
# 334    703593  Perfect Located HOUSE Cihangir BEYOGLU   2769925        Pelin
# 1486  3093528       Comfortable Apartment Sultanahmet  15732904   Ozan Özgür
# 3204  6549527   Spectacular view and Bright apartment  34255768        Osman
# 3274  6664471       Charming apartment in Sultanahmet  17975030       Hikmet
# 1550  3237666            cozy room in Taksim Istanbul   2475490       Ceylan
# 227    555588     Historical Istanbul House @ Taksim    2731976       Alexis
# 348    718917       Fancy Flat near Taksim Square (7)   1605466        Kerem
#
#      neighbourhood  latitude  longitude        room_type  price  \
# 652   Bahcelievler  40.99240   28.83904     Private room    153
# 469        Beyoglu  41.03358   28.98310  Entire home/apt    153
# 891          Fatih  41.00314   28.97802  Entire home/apt    316
# 334        Beyoglu  41.02976   28.98159  Entire home/apt    153
# 1486         Fatih  41.00689   28.96987  Entire home/apt    216
# 3204       Beyoglu  41.03006   28.98006  Entire home/apt    322
# 3274         Fatih  41.00661   28.96972  Entire home/apt    195
# 1550       Beyoglu  41.03397   28.98620     Private room    148
# 227          Sisli  41.04251   28.98788  Entire home/apt    243
# 348        Beyoglu  41.03862   28.98308  Entire home/apt    179
#
#       minimum_nights  number_of_reviews  reviews_per_month  \
# 652                1                307               4.39
# 469                2                276               3.74
# 891                1                272               4.12
# 334                2                267               3.48
# 1486               2                264               4.62
# 3204               1                253               5.73
# 3274               1                251               5.61
# 1550               1                248               4.48
# 227                3                246               3.08
# 348                1                240               4.18
#
#       calculated_host_listings_count  availability_365
# 652                                3               362
# 469                                7               127
# 891                                2               331
# 334                                7                79
# 1486                               2               195
# 3204                               1               201
# 3274                               9               322
# 1550                               4                86
# 227                                2               258
# 348                               13               312

# %%
price_avrg=most_reviewed.price.mean()
print('Average price per night: {}'.format(price_avrg))
# Out:
# Average price per night: 207.8

# %%
df[df["host_id"]==21907588].head(5)
# Out:
#            id                                              name   host_id  \
# 2095  4221645                   Cosy studio flat w/ kitchenette  21907588
# 2254  4584562     ** Amazing room w/private bath in Sultanahmet  21907588
# 2255  4584867     ** Deniz Houses Hotel-Double room Sultanahmet  21907588
# 2262  4594357         ** Sea view room w/balcony in Sultanahmet  21907588
# 2271  4627130  *** Naz Wooden House  Inn - old city of Istanbul  21907588
#
#      host_name neighbourhood  latitude  longitude        room_type  price  \
# 2095    Alihan         Fatih  41.00630   28.96519  Entire home/apt    105
# 2254    Alihan         Fatih  41.00237   28.97515     Private room    100
# 2255    Alihan         Fatih  41.00207   28.97373     Private room    105
# 2262    Alihan         Fatih  41.00381   28.97516     Private room    185
# 2271    Alihan         Fatih  41.00417   28.97923     Private room    127
#
#       minimum_nights  number_of_reviews  reviews_per_month  \
# 2095              60                 40               0.77
# 2254               1                 18               0.36
# 2255               1                115               2.30
# 2262               1                 20               0.43
# 2271               1                101               2.00
#
#       calculated_host_listings_count  availability_365
# 2095                              77               266
# 2254                              77               358
# 2255                              77               359
# 2262                              77               357
# 2271                              77               341
